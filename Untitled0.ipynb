# %%
# This mounts your Google Drive to the Colab VM.
DatafolderName = '/content/drive/MyDrive/Colab/proj/'
assert DatafolderName is not None, "[!] Enter the foldername."

import sys
sys.path.append(DatafolderName)

from google.colab import drive
drive.mount('/content/drive/')

import os
os.chdir(DatafolderName)
# Out:
# Mounted at /content/drive/

# %%
# !python OU_KF.py
# Out:
# using GPU!
# Running on the GPU
# OU_Experiment Start
# Current Time = 04.23.22_08:33:35
# 1/r2 [dB]:  tensor(-10.)
# 1/q2 [dB]:  tensor(-10.)
# KF - MSE MEAN: tensor(6.3352) [dB]
# KF - MSE STD: tensor(-0.6610) [dB]
# Number of trainable parameters for KNet: 472
# 0 MSE Training : tensor(-1.2640) [dB] MSE Validation : tensor(0.1635) [dB]
# Optimal idx: 0 Optimal : tensor(0.1635) [dB]
# 1 MSE Training : tensor(-0.8471) [dB] MSE Validation : tensor(-0.4551) [dB]
# Optimal idx: 1 Optimal : tensor(-0.4551) [dB]
# 2 MSE Training : tensor(-1.5164) [dB] MSE Validation : tensor(-1.0242) [dB]
# diff MSE Training : tensor(-0.6694) [dB] diff MSE Validation : tensor(-0.5691) [dB]
# Optimal idx: 2 Optimal : tensor(-1.0242) [dB]
# 3 MSE Training : tensor(-1.3235) [dB] MSE Validation : tensor(-1.4572) [dB]
# diff MSE Training : tensor(0.1930) [dB] diff MSE Validation : tensor(-0.4330) [dB]
# Optimal idx: 3 Optimal : tensor(-1.4572) [dB]
# ...
